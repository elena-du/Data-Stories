# %% [markdown]
# # Data Visualization with Matplotlib

# %% [markdown]
# **Matplotlib** is one of the core libraries for data visualization in Python. You will use it to create and customize charts - line charts, bar charts, scatter plots, and histograms.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('UO98lJQ3QGI', width=560)

# %% [markdown]
# ## Import Libraries

# %% [markdown]
# Note that **%matplotlib inline** line of code allows the visuals to render within your Jupyter Notebook.

# %%
import numpy as np
import pandas as pd
import random

import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Create charts

# %% [markdown]
# Matplotlib accepts data structures you are familiar with.

# %% [markdown]
# #### a) a list

# %% [markdown]
# Let's first create a list of 10 random integers and let their values be in the range from 10 to 30. You can consider using **sample()** function from **random** library and base function **range()**. Feel free to come up with an alternative solution. Set the seed to **123** for reproducibility.

# %%
random.seed(123)
my_list = #Code here 
my_list
# Out:
# [11, 18, 12, 23, 28, 29, 26, 10, 16, 25]

# %% [markdown]
# Now let's plot the list of numbers with basic **plot** function of our matplotlib library. Just pass your list to the function as an argument.

# %%
plt.plot(my_list);

# %% [markdown]
# Try to put **;** at the end of your coding statement. What role does it play?

# %% [markdown]
# Type your answer here

# %% [markdown]
# What are the values on the y-axes? on the x-axis?

# %% [markdown]
# Type your answer here

# %% [markdown]
# You can control the numbers on x-axis as well. Assign a list of 10 consecutive integers starting with 100 to x variable, pass it as a first argument to **plot()** function.

# %%
x = range(100,110)
plt.plot(x, my_list);

# %% [markdown]
# #### b) an array

# %% [markdown]
# Now create the same chart using an array. To obtain an array, use the list you created above and **numpy** library.

# %%
my_array = np.array(my_list)
plt.plot(my_array);

# %% [markdown]
# #### c) pandas Series and DataFrame

# %% [markdown]
# Now create the same chart using **pandas**. Try to convert your list to both series and data frame objects and plot the same graph.

# %%
my_pandas_series = pd.Series(my_list)
plt.plot(my_pandas_series);

# %%
my_df = pd.DataFrame(my_list)
plt.plot(my_df);

# %% [markdown]
# ## Add aesthetics

# %% [markdown]
# #### a) add title

# %% [markdown]
# Think layers when building charts with matplotlib. As an example, to add a title to your plot you can just add another line of code and use **title()** function.

# %%
plt.plot(my_list)
plt.title('My First Plot');

# %% [markdown]
# You have control over text properties, see official documentation here:  https://matplotlib.org/users/text_props.html. Experiment with text properties of your title, come up with the style you like. Be sure to use *family*, *fontsize*, *loc*, and *color* arguments.

# %%
plt.plot(my_list)
plt.title('My First Plot',family='serif',fontsize = 30,loc='left',color='g');

# %% [markdown]
# #### b) add axes labels

# %% [markdown]
# Similarly, explore **xlabel()** and **ylabel()** functions and add those to your plot.

# %%
plt.plot(my_list)
plt.title('My First Plot',family='serif',fontsize = 30,loc='left',color='g')
plt.xlabel('Label on the X axis',fontsize = 15, weight = 'bold',color='g')
plt.ylabel('Label on the Y axis',fontsize = 15, weight = 'bold',color='g');

# %% [markdown]
# Now, let's recap the basics. For that, create a dataset that contains the values from 0 to 50 in increments of 0.01 for the $x$ value, and $sin(x) + cos(2x)$ for the $y$ value. You can use **arange()**, **sin()**, **cos()** functions from **numpy** package. Include a title and labels for the $x$ and $y$ axis. Propose your version of the format of the text.

# %% [markdown]
# $$y=sin(x) + cos(2x)$$

# %%
x = np.arange(0,50,step=0.01)
y = np.sin(x)+np.cos(2*x)

plt.plot(x,y)
plt.title('Wave Line Chart', fontsize= 20,family='serif')
plt.xlabel('X-Axis', fontsize= 15,family='sans-serif')
plt.ylabel('Y-Axis', fontsize= 15,family='sans-serif');

# %% [markdown]
# #### c) add title gridlines

# %% [markdown]
# You can add gridlines with **grid()** function from **matplotlib** library to your plot of the sine wave.

# %%
plt.plot(x,y)
plt.title('Wave Line Chart', fontsize= 20,family='serif')
plt.xlabel('X-Axis', fontsize= 15,family='sans-serif')
plt.ylabel('Y-Axis', fontsize= 15,family='sans-serif')
plt.grid();

# %% [markdown]
# #### d) add ticks

# %% [markdown]
# You can also control the location of the ticks with **xticks()** and **plt.yticks()** functions from **matplotlib** library. Force the ticks on the y-axis to be a vector of two values, including -1 and 1.Force the ticks on the x-axis to be a vector of three values, including 0, 25 and 50.

# %%
ticks_x = np.linspace(0, 50, 3)


plt.plot(x,y)
plt.title('Wave Line Chart', fontsize= 20,family='serif')
plt.xlabel('X-Axis', fontsize= 15,family='sans-serif')
plt.ylabel('Y-Axis', fontsize= 15,family='sans-serif')
plt.grid()

plt.xticks(ticks_x)
plt.yticks([-1, 1]);

# %% [markdown]
# Now, let's add some strings as ticks. On the $y$-axis let's keep two ticks we got, but let's lable them **'top'** and **'bottom'** instead. To figure out how to do that see the documentation of the function.

# %%
ticks_x = np.linspace(0, 50, 3)

plt.plot(x,y)
plt.title('Wave Line Chart', fontsize= 20,family='serif')
plt.xlabel('X-Axis', fontsize= 15,family='sans-serif')
plt.ylabel('Y-Axis', fontsize= 15,family='sans-serif')
plt.grid()

plt.xticks(ticks_x)
plt.yticks([-1, 1], labels=['bottom', 'top']);

# %% [markdown]
# #### e) add more lines

# %% [markdown]
# Think layers again! Add a cosine wave to your plot. To do that you can use a **plot()** function several times. Make sure you rename the plot appropriately!

# %%
ticks_x = np.linspace(0, 50, 3)

plt.plot(x,y)
plt.plot(x,np.cos(x))
plt.title('Wave Line Chart', fontsize= 20,family='serif')
plt.xlabel('X-Axis', fontsize= 15,family='sans-serif')
plt.ylabel('Y-Axis', fontsize= 15,family='sans-serif')
plt.grid()

plt.xticks(ticks_x)
plt.yticks([-1, 1], labels=['bottom', 'top']);

# %% [markdown]
# Python and **Matplotlib** took care of coloring for you. But we need to make sure it is clear what color represetns which of the two waves. To achieve this, let's use **legend()** function from **matplotlib**. What is the best spot for the legend in your opinion?

# %%
ticks_x = np.linspace(0, 50, 3)

plt.plot(x,y)
plt.plot(x,np.cos(x))
plt.title('Wave Line Chart', fontsize= 20,family='serif')
plt.xlabel('X-Axis', fontsize= 15,family='sans-serif')
plt.ylabel('Y-Axis', fontsize= 15,family='sans-serif')
plt.grid()

plt.xticks(ticks_x)
plt.yticks([-1, 1], labels=['bottom', 'top'])
plt.legend(['Wave','Cosine Wave'], bbox_to_anchor=(1.0, 1));

# %% [markdown]
# #### f) control colors

# %% [markdown]
# You can declare a color:
# * by name (https://matplotlib.org/api/_as_gen/matplotlib.pyplot.colors.html),
# * by alias (https://www.w3schools.com/cssref/css_colors.asp), or
# * by RGB color code.
#
# Let's output our sine wave in magenta color and out cosine wave in cyan.

# %%
ticks_x = np.linspace(0, 50, 3)

plt.plot(x,y, c='m')
plt.plot(x,np.cos(x), c='c')
plt.title('Wave Line Chart', fontsize= 20,family='serif')
plt.xlabel('X-Axis', fontsize= 15,family='sans-serif')
plt.ylabel('Y-Axis', fontsize= 15,family='sans-serif')
plt.grid()

plt.xticks(ticks_x)
plt.yticks([-1, 1], labels=['bottom', 'top'])
plt.legend(['Sine Wave','Cosine Wave'], bbox_to_anchor=(1.0, 1));

# %% [markdown]
# #### g) control line width

# %% [markdown]
# Use *linewidth* parameter for that. Let's make our sine wave noticeably thicker than the cosine one.

# %%
ticks_x = np.linspace(0, 50, 3)

plt.plot(x,y, c='m', linewidth=3)
plt.plot(x,np.cos(x), c='c', linewidth=0.7)
plt.title('Wave Line Chart', fontsize= 20,family='serif')
plt.xlabel('X-Axis', fontsize= 15,family='sans-serif')
plt.ylabel('Y-Axis', fontsize= 15,family='sans-serif')
plt.grid()

plt.xticks(ticks_x)
plt.yticks([-1, 1], labels=['bottom', 'top'])
plt.legend(['Sine Wave','Cosine Wave'], bbox_to_anchor=(1.0, 1));

# %% [markdown]
# #### h) control line style

# %% [markdown]
# Finally, lines do not have to be solid. You can control the visualization with a *linestyle* parameter.  Find out more here https://matplotlib.org/gallery/lines_bars_and_markers/line_styles_reference.html. Let's make your sine wave dashed.

# %%
ticks_x = np.linspace(0, 50, 3)

plt.plot(x,y, c='m', linewidth=3, linestyle='--')
plt.plot(x,np.cos(x), c='c', linewidth=0.7)
plt.title('Wave Line Chart', fontsize= 20,family='serif')
plt.xlabel('X-Axis', fontsize= 15,family='sans-serif')
plt.ylabel('Y-Axis', fontsize= 15,family='sans-serif')
plt.grid()

plt.xticks(ticks_x)
plt.yticks([-1, 1], labels=['bottom', 'top'])
plt.legend(['Sine Wave','Cosine Wave'], bbox_to_anchor=(1.0, 1));

# %% [markdown]
# ## Types of Charts

# %% [markdown]
# Let's cover the basics using a real dataset. Create a data frame from **Kickstarter** .csv file. Use the clean file that you wrote to your working directory after cleaning. Feel free to use **pandas** functions to see the data when you need it.

# %%
df = pd.read_csv('kickstarter_clean.csv')

# %%
df.head()
# Out:
#    Unnamed: 0          ID                                      name  \
# 0           0   239894312                                  Barwagen
# 1           1   353169821    StrongMACH Customs muscle car replicas
# 2           2  1387928487  Cravin' Dogs 30th anniversary CD project
# 3           3   735160267            A Socially Awkward fundraiser!
# 4           4  1838469271                                MechRunner
#
#   main_category currency  deadline      goal        launched  pledged  \
# 0        Crafts      CHF  11/30/17     500.0  10/23/17 19:32     15.0
# 1           Art      USD   10/3/16  100000.0    8/4/16 18:29      0.0
# 2         Music      USD  10/27/16   12500.0   9/27/16 16:40   1180.0
# 3       Theater      GBP   9/14/17    1500.0   7/16/17 16:33   1500.0
# 4         Games      USD   5/17/14   25000.0   4/13/14 20:57  28434.0
#
#         state  backers country  usd.pledged
# 0      failed      2.0      CH         0.00
# 1      failed      0.0      US         0.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     2000 non-null   int64
#  1   ID             2000 non-null   int64
#  2   name           2000 non-null   object
#  3   main_category  2000 non-null   object
#  4   currency       2000 non-null   object
#  5   deadline       2000 non-null   datetime64[ns]
#  6   goal           2000 non-null   float64
#  7   launched       2000 non-null   datetime64[ns]
#  8   pledged        2000 non-null   float64
#  9   state          2000 non-null   object
#  10  backers        2000 non-null   float64
#  11  country        2000 non-null   object
#  12  usd.pledged    2000 non-null   float64
# dtypes: datetime64[ns](2), float64(4), int64(2), object(5)
# memory usage: 203.2+ KB

# %%
df['deadline'] = pd.to_datetime(df['deadline'])

# %%
df['launched'] = pd.to_datetime(df['launched'])

# %% [markdown]
# #### a) line charts

# %% [markdown]
# This one you know already. Plot revenue goals.

# %%
plt.plot(df['launched'], df['goal'])

# %% [markdown]
# Nice. What do values on the x-axis represent? Now, there is an additional challenge for you. Try to plot revenue goals over time the campaigns were launched. Think what kind of familiar **pandas** functions you can use to make it look right.

# %%
df.sort_values(by=['launched'], inplace=True)
plt.plot(df['launched'], df['goal']);

# %% [markdown]
# #### b) bar charts

# %% [markdown]
# Use **bar()** function to see the counts of observations by state.

# %%
plt.bar(df['main_category'],df['goal']);

# %% [markdown]
# To make it more readable, let's convert it to horisontal bar chart. For that let's use **barh()** function.

# %%
plt.barh(df['main_category'],df['goal']);

# %% [markdown]
# This is better. Did you notice that it takes a second to render a graph? To speed it up we can create a summary table before trying to plot the graph. It will be also easy to sort it then. Don't worry about the code to create a summary table for now. Just print it out and see if it makes sense to you.

# %%
summary = df.groupby(['main_category'])[['goal']].mean().sort_values(by='goal', ascending=True).reset_index()
summary
# Out:
#    main_category          goal
# 0          Dance   5373.333333
# 1        Theater   8155.949367
# 2         Comics   8338.622642
# 3    Photography  10280.680851
# 4     Publishing  11101.381818
# 5         Crafts  12446.600000
# 6          Music  12554.444030
# 7     Journalism  17071.250000
# 8        Fashion  17962.899160
# 9         Design  21317.472973
# 10           Art  21750.733333
# 11  Film & Video  28384.962099
# 12         Games  32332.302703
# 13          Food  35898.062937
# 14    Technology  56562.011834

# %% [markdown]
# Now, plot the same graph, but use the **'summary'** dataframe.

# %%
plt.barh(summary['main_category'],summary['goal']);

# %% [markdown]
# #### c) scatterplots

# %% [markdown]
# Use **scatter()** function to plot the relationships between number of backers and amount of revenue pledged.

# %%
plt.scatter(df['backers'],df['pledged']);

# %% [markdown]
# To make the relationship more visible, let's transform both variables with **log()** function from **numpy** library.

# %%
plt.scatter(np.log(df['backers']),np.log(df['pledged']));
# Out:
# /usr/local/lib/python3.9/site-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# How can you describe the relaionship?

# %% [markdown]
# Type your answer here

# %% [markdown]
# #### d) histograms

# %% [markdown]
# Finally, let's see the distrubution of goals present in the dataset. Use **hist()** function from **matplotlib** library.

# %%
plt.hist(df['goal']);

# %% [markdown]
# Does it make sense? Use an appropriate mask to get rig of outliers. Can you make this histogram more insightful?

# %%
plt.hist(df[df['goal'] < 100000]['goal']);

# %% [markdown]
# What conclusion can you draw out of your experiments with hiatograms of revenue goals?

# %% [markdown]
# Type your answer here

# %% [markdown]
# Great! You know the basics of plotting in Python!
